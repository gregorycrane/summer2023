# %%
import re

hitdict = {}
workdict = {}


def additem(curitem,curdict):
    if(curitem in curdict):
        curdict[curitem] = curdict[curitem] + 1
    else:
        curdict[curitem] = 1
def getcits(fname):
    
    f = open(fname)
    curhits = 0
    for l in f:
        hits = re.findall('([A-Z][a-z \.,]+)\s+<title[^>]*>([^<]+)',l)

        for hit in hits:

            if(not hit[1][0].isupper()):
                #print('skipping',hit)
                continue
            curhits = curhits + 1
            additem(hit,hitdict)
            additem(hit[1],workdict)
            #print(curhits,hit,type(hit),hit[1])
    f.close()


getcits('lucian_1888.xml')

print(len(workdict))

for foo in sorted(workdict,key=workdict.get,reverse=True):
    print(foo,workdict[foo])
# Out:
# 196
# Θ. Δ. 28
# Ἰλ. 20
# Aen. 16
# Ὀδ. 9
# Ὀδ 7
# Νεφ 5
# Ὄρνιθες 5
# Ἰλ 4
# Βατρ 4
# Νεκ. Διαλ. 4
# Προμ. Δεσμ 3
# Συμπ 3
# Εἴκονες 3
# Ἀλεξ. 3
# Φαίδων 3
# Θεογ 2
# Ἱκέτιδες 2
# Ὀλ. 2
# Περὶ θυσίων 2
# Εἰδ 2
# Βάκχαι 2
# Χάρων 2
# Κυροπ 2
# Πλου̃τος 2
# Γεωγ. 2
# Περὶ Βίων 2
# Περὶ Πένθους 2
# Βίοι Παρ. 2
# Ἀνάβασις 2
# Ἀληθὴς Ἱστορία 2
# Πολ. 2
# Χάρων 2
# Περὶ θυσίων 2
# Ἀχαρ 2
# Ὄρνιθ 2
# Νεφ. 2
# Ἐναλ. Διαλ 1
# Προμήθευς Δεσμώτης 1
# Περὶ Ὀρχήσεως 1
# Λυσιστράτη 1
# Κρατύλος 1
# Βίοι Παραλ. 1
# Συμπόσιον 1
# Ἐκκλης 1
# Ἄσπις Ἡρακ. 1
# Ἀδωνιάζουσαι 1
# Είδύλλιον 1
# Συμπόσιον ἢ Λάπιθαι 1
# Εἰδ. 1
# Προτρεπτ 1
# Περὶ   Παλ. βαλ 1
# Πόλ 1
# Δειπ 1
# Ἱστ. Ποικ 1
# Περί τη̃ς Σαρκοφαγίας 1
# Εἰρήνη 1
# Ἰκάρο-Μενίππος 1
# Ἑταίρα 1
# Αυσίστρατα 1
# Ἀληθὴς Ἱστ. 1
# Ἑλ. Περ. 1
# Ζεὺς Ἐλεγ. 1
# Ειδ 1
# Ἀργοναύτ. 1
# Νεκρ. Δίαλ. 1
# Εἰδ 1
# Ἐπ 1
# Εἰκόνες 1
# Κύκλωψ 1
# Βίβ. Ἱστ. 1
# Εἲκονες 1
# Ἀλ. Ἱστ. 1
# Ἁλ. 1
# Εἳκονες 1
# Φαινομ 1
# Πύθ. 1
# Μηδ. 1
# Περἰ Ζώων Ἰδιότ. 1
# Ἀπολλών 1
# Δἰς Κατηγορουύμενος 1
# Συμπ. 1
# Αἰθιοπ. 1
# Στρωμ 1
# Πλ. 1
# Ἀλκιβιάδης 1
# Περὶ τῶν ἔπι Μισθῳ̃ Συνόντων 1
# Ἁλιεύς. 1
# Πολιτ. 1
# Τίμων 1
# Λεξιφ. 1
# Μισοπώγων 1
# Δημώναξ 1
