# %%
import re
import os

volumeinfo = {
    
    '1': 'The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.',
    '2': 'The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.',
    '3': 'The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.',
    '4': 'The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.'


}

refsbook = ['<refsDecl n="CTS">',
  '<cRefPattern matchPattern="(\w+).(\w+)"',
   'replacementPattern="#xpath(/tei:TEI/tei:text/tei:body/tei:div/tei:div[@n=\'$1\']/tei:div[@n=\'$2\'])">',
   '<p>This pointer pattern extracts book and section</p>',
  '</cRefPattern>',
  '<cRefPattern matchPattern="(\w+)"',
   'replacementPattern="#xpath(/tei:TEI/tei:text/tei:body/tei:div/tei:div[@n=\'$1\'])">',
   '<p>This pointer pattern extracts book</p>',
  '</cRefPattern>',
 '</refsDecl>']

refssection = ['<refsDecl n="CTS">',
   '<cRefPattern matchPattern="(\w+)"',
    'replacementPattern="#xpath(/tei:TEI/tei:text/tei:body/tei:div/tei:div[@n=\'$1\'])">',
    '<p>This pointer pattern extracts section.</p>',
   '</cRefPattern>',
  '</refsDecl>']


tgroup = 'tlg0062'
edition = 'perseus-eng4'
worktitles = {}
hasbooks = {}
firstpages = {}
metadata = {}

worklines = {}


def normcase(s):
    stopwords = ['a','an','and','in','is','of','on','or','that','the','with']
    returns  = ''
    
    curwork = ''
    for foo in s.split():
        foo = foo.lower()
        if(not foo in stopwords):
            foo = re.sub('^(.)',foo[0].upper(),foo)
        returns = returns + ' ' + foo
        
    returns = re.sub('^\s*(.+)\s*$','\g<1>',returns)        
    ucase = returns[0].upper() 
    returns = re.sub('^(.)',returns[0].upper(),returns)
    return(returns)

def add2teiheader(l,teiheader):
    
    if(re.search('<name xml:lang="en">H. W. Fowler</name>',l)):
        teiheader.append('<name>Henry Watson Fowler</name>')
        return
    
    if(re.search('<name xml:lang="en">F. G. Fowler</name>',l)):
        teiheader.append('<name>Francis George Fowler</name>')
        return
    l = re.sub('"en"','"eng"',l)
    
    if(re.search('<resp>',l)):
        teiheader.append('<resp>Digital conversion and editing</resp>')
        return
    
    l = re.sub('<editor>','<editor role="translator">',l)
    
    if(re.search('</teHeader',l)):
        teiheader.append('<revisionDesc>')
        teiheader.append('<change when="2023-08-01" who="Gregory Crane">GRC found this file largely tagged but cannot find a record (or remember) how it was originally entered. He did the final work to make this compatible with Scaife.</change>')
        teiheader.append('</revisionDesc>')
    
    teiheader.append(l)
    if(re.search('Library</authority',l)):
        teiheader.append('<idno type="filename">IDNO</idno>')

def splitvol(volnum):
    global worklines
    global volumeinfo
    fname = 'lucian-vol' + volnum + '-eng.xml'
    f = open(fname)
    curpage = ''
    curwork = ''
    sawtitle = 0
    intext = 0
    teiheader = []
    worklines = {}
    
    curpagelink = 'https://archive.org/details/worksoflucianofs0'+volnum+'luciuoft/page/PNUM/mode/1up'
    
    for l in f:
        l = re.sub('\s+$','',l)
        
        if(re.search('<text',l)):
            intext = 1
        
        if(not intext):
            l = re.sub('target="(https://archive[^"]+)','target="'+curpagelink,l)
            if(re.search('<title ',l)):
                if(not sawtitle):
                    l = '<title xml:lang="eng">WORKTITLE</title>'
                    sawtitle = 1
            add2teiheader(l,teiheader)
            continue
            
        m = re.search('<pb n="([0-9]+)',l)
        if(m):
            curpage = m[1]
            
        if(re.search('subtype="book"',l)):
            hasbooks[curwork] = 1
            
        m = re.search('(tlg006[12].tlg[0-9]+)',l)
        if(m):
            curwork = m[1]
            metadata[curwork] = volumeinfo[volnum]
            if(curpage and not curwork in firstpages):
                firstpages[curwork] = curpage
            else:
                print('nofirstpage',curwork)
            #print(curwork,curpage)
            
        m =  re.search('<head>([^<]+)',l)
        if(m and not curwork in worktitles):
            curhead = normcase(m[1])
            worktitles[curwork] = curhead
            #print(volnum,curwork,curhead)
    
    f.close()
    
    
    transbase = '<div type="translation" n="urn:cts:greekLit:tlg0062.tlg001.perseus-eng4" xml:lang="eng">'
    trans = ''
    f = open(fname)
    
    curwork = ''
    
    for l in f:
        l = re.sub('\s+$','',l)
        m = re.search('(tlg006[12]\.tlg[0-9]+)',l)
        if(m):
            curwork = m[1]
            worklines[curwork] = []
            worklines[curwork].append('<text xml:lang="eng">')
            worklines[curwork].append('<body>')
            trans = re.sub('tlg006[12]\.tlg001',curwork,transbase)
            worklines[curwork].append(trans)
            continue
        if(re.search('</TEI>',l)):
            continue
            
        if(curwork):
            worklines[curwork].append(l)
            
            
    
    f.close()
    
    for curwork in worklines:
        xmlfile = curwork + '.' + edition + '.xml'
        outfname = '/Users/gcrane/github/first1kwork/data/' + re.sub('(tlg006[12])\.(tlg[0-9]+)','\g<1>/\g<2>/',curwork) + xmlfile
        print(outfname)
        outf = open(outfname,'w')

        curbook = ''
        cursection = ''
        inrefsdecl = 0
        for l in teiheader:
            l = re.sub('<date>2023','<date type="release">2023-08-01',l)
            if(re.search('WORKTITLE',l)):
                l = re.sub('WORKTITLE',worktitles[curwork],l)
                l = l + '\n<author>Lucian</author>'
                l = l + '\n<editor role="translator">Henry Watson Fowler</editor>'
                l = l + '\n<editor role="translator">Francis George Fowler</editor>'
            l = re.sub('IDNO',xmlfile,l)
            l = re.sub('PNUM',firstpages[curwork],l)
            if(re.search('<refsD',l)):
                inrefsdecl = 1
                if(curwork in hasbooks):
                    curf = open('bookref.txt')
                    for line in curf:
                        print(line,file=outf,end='')
                else:
                    curf = open('sectionref.txt')
                    for line in curf:
                        print(line,file=outf,end='')
                continue
            if(re.search('</refsD',l)):
                inrefsdecl = 0
                continue
            if(inrefsdecl):
                continue
                
            
            print(l,file=outf)
        curpage = ''
        for l in worklines[curwork]:
            
            m = re.search('<pb n="([0-9]+)"',l)
            if(m):
                curpage = 'v.' + volnum + '.p.' + m[1]
                l = re.sub('<pb n="([0-9]+)"','<pb n="'+curpage+'"',l)
                
            l = re.sub('(<note[^>*])n="([0-9]+)\.([0-9]+)"','\g<1>n="v.'+volnum+'.p.\g<2>.n.\g<3>"',l)
            
            while(re.search('(<note[^>]*>)(.+?</note>)',l)):
            
                m = re.search('(<note[^>]*>)(.+?</note>)',l)
                if(m):
                    notetext = m[2]
                    if(re.search('[α-ω]',notetext)):
                        l = re.sub('(<note)([^>]*>.+?</note>)','<xnote xml:lang="mul"\g<2>',l,1)
                    else:
                        l = re.sub('(<note)([^>]*>.+?</note>)','<xnote xml:lang="eng"\g<2>',l,1)
            l = re.sub('<xnote','<note',l)
            
            #l = re.sub('<note','<note xml:lang="eng"',l)
            m = re.search('<div[^>]+subtype="book" n="([^"]+)"',l)
            if(m):
                curbook = m[1]
                l = re.sub('(subtype="[^"]+")','\g<1> xml:base="urn:cts:greekLit:'+curwork+'.'+edition+'"',l)
                
            m = re.search('<div[^>]+subtype="section" n="([^"]+)"',l)
            if(m):
                cursection = m[1]
                l = re.sub('(subtype="[^"]+")','\g<1> xml:base="urn:cts:greekLit:'+curwork+'.'+edition+':'+curbook+'"',l)
           
            l = re.sub('<note>','<note xml:lang="eng">',l)
            print(l,file=outf)
            
        print('</body></text></TEI>',file=outf)
        outf.close()

        


for i in range(1,5):
    splitvol(str(i))
    
 
#don't add these again
for i in range(1,71):
    #continue
    if(i<10):
        curwork = 'tlg0062.tlg00' + str(i)    
    elif(i<100):
        curwork = 'tlg0062.tlg0' + str(i)
        
    if(not curwork in worktitles):
        print('\n'+curwork,'skipped')
        continue
        
        #print(curwork,edition,worktitles[curwork],metadata[curwork])
    #else:
    newfname = 'ctsfiles/' + curwork + '-cts.xml'
    if(os.path.exists(newfname) and 0):
        print('exists',newfname)
    else:
        xmlfile = curwork + '.' + edition + '.xml'

        fname = '/Users/gcrane/github/canonical-greekLit/data/tlg0062/' + re.sub('tlg006[12]\.(tlg[0-9]+)','\g<1>/',curwork) + '__cts__.xml'

        f = open(fname)
    
        text = f.read()
        f.close()
        outf = open(newfname,'w')
        outf.write(text)
        print('created',newfname)
    
    outfname = '/Users/gcrane/github/first1kwork/data/' + re.sub('(tlg006[12])\.(tlg[0-9]+)','\g<1>/\g<2>/',curwork) + '__cts__.xml'
    newfname = '/Users/gcrane/github/canonical-greekLit/data/tlg0062/' + re.sub('tlg006[12]\.(tlg[0-9]+)','\g<1>/',curwork) + '__cts__.xml'

    f = open(newfname)
    text = f.read()
    outf = open(outfname,'w')
    print('outfname',outfname)
    
            
    fullmeta = '<ti:translation urn="urn:cts:greekLit:'+curwork+'.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:'+curwork+'">\n'
    fullmeta = fullmeta + '<ti:label xml:lang="eng">' + worktitles[curwork] + '</ti:label>\n'
    fullmeta = fullmeta + '<ti:description xml:lang="eng">' + metadata[curwork] + '</ti:description>\n\n</ti:translation>\n\n</ti:work>\n'
    
    newtext = re.sub('</ti:work>',fullmeta,text)
    outf.write(newtext)
    print('writing',outfname,fullmeta)
    outf.close()
    #print('\n'+text+'\n')
# Out:
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg029/tlg0062.tlg029.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg064/tlg0062.tlg064.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg007/tlg0062.tlg007.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg014/tlg0062.tlg014.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg022/tlg0062.tlg022.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg020/tlg0062.tlg020.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg068/tlg0062.tlg068.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg067/tlg0062.tlg067.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg066/tlg0062.tlg066.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg035/tlg0062.tlg035.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg023/tlg0062.tlg023.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg027/tlg0062.tlg027.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg024/tlg0062.tlg024.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg025/tlg0062.tlg025.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg016/tlg0062.tlg016.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg033/tlg0062.tlg033.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg059/tlg0062.tlg059.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg058/tlg0062.tlg058.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg063/tlg0062.tlg063.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg056/tlg0062.tlg056.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg057/tlg0062.tlg057.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg060/tlg0062.tlg060.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg062/tlg0062.tlg062.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg053/tlg0062.tlg053.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg012/tlg0062.tlg012.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg051/tlg0062.tlg051.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg052/tlg0062.tlg052.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg001/tlg0062.tlg001.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg038/tlg0062.tlg038.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg045/tlg0062.tlg045.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg046/tlg0062.tlg046.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg008/tlg0062.tlg008.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg039/tlg0062.tlg039.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg040/tlg0062.tlg040.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg044/tlg0062.tlg044.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg017/tlg0062.tlg017.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg018/tlg0062.tlg018.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg019/tlg0062.tlg019.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg021/tlg0062.tlg021.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg026/tlg0062.tlg026.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg030/tlg0062.tlg030.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg034/tlg0062.tlg034.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg036/tlg0062.tlg036.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg037/tlg0062.tlg037.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg031/tlg0062.tlg031.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg003/tlg0062.tlg003.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg004/tlg0062.tlg004.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg005/tlg0062.tlg005.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg006/tlg0062.tlg006.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg028/tlg0062.tlg028.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg013/tlg0062.tlg013.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg009/tlg0062.tlg009.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg010/tlg0062.tlg010.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg054/tlg0062.tlg054.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg061/tlg0062.tlg061.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg065/tlg0062.tlg065.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg069/tlg0062.tlg069.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg042/tlg0062.tlg042.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg043/tlg0062.tlg043.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg055/tlg0062.tlg055.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg015/tlg0062.tlg015.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0061/tlg003/tlg0061.tlg003.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg050/tlg0062.tlg050.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0061/tlg006/tlg0061.tlg006.perseus-eng4.xml
# /Users/gcrane/github/first1kwork/data/tlg0062/tlg070/tlg0062.tlg070.perseus-eng4.xml
# created ctsfiles/tlg0062.tlg001-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg001/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg001/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg001.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg001">
# <ti:label xml:lang="eng">Phalaris, I</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
#
# tlg0062.tlg002 skipped
# created ctsfiles/tlg0062.tlg003-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg003/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg003/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg003.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg003">
# <ti:label xml:lang="eng">Dionysus, an Introductory Lecture</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg004-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg004/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg004/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg004.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg004">
# <ti:label xml:lang="eng">Heracles, an Introductory Lecture</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg005-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg005/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg005/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg005.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg005">
# <ti:label xml:lang="eng">Swans and Amber</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg006-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg006/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg006/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg006.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg006">
# <ti:label xml:lang="eng">The Fly, an Appreciation</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg007-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg007/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg007/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg007.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg007">
# <ti:label xml:lang="eng">Nigrinus</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg008-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg008/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg008/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg008.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg008">
# <ti:label xml:lang="eng">Life of Demonax</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg009-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg009/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg009/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg009.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg009">
# <ti:label xml:lang="eng">The Hall</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg010-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg010/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg010/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg010.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg010">
# <ti:label xml:lang="eng">Patriotism</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
#
# tlg0062.tlg011 skipped
# created ctsfiles/tlg0062.tlg012-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg012/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg012/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg012.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg012">
# <ti:label xml:lang="eng">The True History</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg013-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg013/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg013/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg013.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg013">
# <ti:label xml:lang="eng">Slander, a Warning</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg014-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg014/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg014/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg014.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg014">
# <ti:label xml:lang="eng">Trial in the Court of Vowels</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg015-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg015/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg015/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg015.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg015">
# <ti:label xml:lang="eng">A Feast of Lapithae</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg016-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg016/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg016/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg016.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg016">
# <ti:label xml:lang="eng">Voyage To the Lower World</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg017-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg017/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg017/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg017.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg017">
# <ti:label xml:lang="eng">Zeus Cross-examined</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg018-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg018/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg018/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg018.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg018">
# <ti:label xml:lang="eng">Zeus Tragoedus</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg019-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg019/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg019/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg019.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg019">
# <ti:label xml:lang="eng">The Cock</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg020-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg020/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg020/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg020.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg020">
# <ti:label xml:lang="eng">Prometheus on Caucasus</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg021-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg021/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg021/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg021.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg021">
# <ti:label xml:lang="eng">Icaromenippus, an Aerial Expedition</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg022-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg022/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg022/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg022.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg022">
# <ti:label xml:lang="eng">Timon the Misanthrope</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg023-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg023/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg023/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg023.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg023">
# <ti:label xml:lang="eng">Charon</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg024-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg024/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg024/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg024.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg024">
# <ti:label xml:lang="eng">Sale of Creeds</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg025-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg025/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg025/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg025.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg025">
# <ti:label xml:lang="eng">The Fisher</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg026-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg026/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg026/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg026.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg026">
# <ti:label xml:lang="eng">The Double Indictment</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg027-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg027/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg027/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg027.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg027">
# <ti:label xml:lang="eng">Of Sacrifice</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg028-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg028/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg028/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg028.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg028">
# <ti:label xml:lang="eng">Remarks Addressed To an Illiterate Book-fancier</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg029-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg029/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg029/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg029.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg029">
# <ti:label xml:lang="eng">A Chapter of Autobiography</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg030-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg030/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg030/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg030.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg030">
# <ti:label xml:lang="eng">The Parasite: a Demonstration that Sponging is a Profession</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg031-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg031/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg031/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg031.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg031">
# <ti:label xml:lang="eng">The Liar</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
#
# tlg0062.tlg032 skipped
# created ctsfiles/tlg0062.tlg033-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg033/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg033/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg033.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg033">
# <ti:label xml:lang="eng">The Dependent Scholar</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg034-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg034/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg034/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg034.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg034">
# <ti:label xml:lang="eng">Anacharsis, a Discussion of Physical Training</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg035-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg035/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg035/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg035.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg035">
# <ti:label xml:lang="eng">Menippus</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg036-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg036/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg036/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg036.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg036">
# <ti:label xml:lang="eng">Of Mourning</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg037-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg037/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg037/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg037.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg037">
# <ti:label xml:lang="eng">The Rhetorician’s Vade Mecum</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg038-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg038/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg038/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg038.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg038">
# <ti:label xml:lang="eng">Alexander the Oracle-monger</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg039-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg039/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg039/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg039.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg039">
# <ti:label xml:lang="eng">A Portrait-study</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg040-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg040/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg040/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg040.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg040">
# <ti:label xml:lang="eng">Defence of the ‘portrait-study’</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
#
# tlg0062.tlg041 skipped
# created ctsfiles/tlg0062.tlg042-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg042/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg042/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg042.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg042">
# <ti:label xml:lang="eng">The Death of Peregrine</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg043-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg043/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg043/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg043.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg043">
# <ti:label xml:lang="eng">The Runaways</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg044-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg044/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg044/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg044.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg044">
# <ti:label xml:lang="eng">Toxaris: a Dialogue of Friendship</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 3. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg045-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg045/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg045/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg045.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg045">
# <ti:label xml:lang="eng">Of Pantomime</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg046-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg046/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg046/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg046.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg046">
# <ti:label xml:lang="eng">Lexiphanes</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
#
# tlg0062.tlg047 skipped
#
# tlg0062.tlg048 skipped
#
# tlg0062.tlg049 skipped
# created ctsfiles/tlg0062.tlg050-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg050/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg050/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg050.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg050">
# <ti:label xml:lang="eng">The Gods in Council</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg051-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg051/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg051/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg051.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg051">
# <ti:label xml:lang="eng">The Tyrannicide</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg052-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg052/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg052/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg052.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg052">
# <ti:label xml:lang="eng">The Disinherited</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg053-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg053/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg053/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg053.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg053">
# <ti:label xml:lang="eng">The Way To Write History</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg054-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg054/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg054/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg054.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg054">
# <ti:label xml:lang="eng">Dipsas, the Thirst-snake</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg055-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg055/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg055/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg055.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg055">
# <ti:label xml:lang="eng">Saturnalia</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg056-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg056/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg056/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg056.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg056">
# <ti:label xml:lang="eng">Herodotus and Aetion</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg057-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg057/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg057/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg057.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg057">
# <ti:label xml:lang="eng">Zeuxis and Antiochus</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg058-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg058/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg058/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg058.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg058">
# <ti:label xml:lang="eng">A Slip of the Tongue in Salutation</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg059-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg059/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg059/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg059.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg059">
# <ti:label xml:lang="eng">Apology For ‘the Dependent Scholar’</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg060-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg060/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg060/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg060.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg060">
# <ti:label xml:lang="eng">Harmonides</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg061-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg061/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg061/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg061.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg061">
# <ti:label xml:lang="eng">A Word with Hesiod</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg062-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg062/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg062/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg062.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg062">
# <ti:label xml:lang="eng">The Scythian</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg063-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg063/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg063/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg063.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg063">
# <ti:label xml:lang="eng">Hermotimus, or the Rival Philosophies</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 2. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg064-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg064/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg064/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg064.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg064">
# <ti:label xml:lang="eng">A Literary Prometheus</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg065-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg065/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg065/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg065.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg065">
# <ti:label xml:lang="eng">The Ship: Or, the Wishes</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg066-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg066/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg066/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg066.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg066">
# <ti:label xml:lang="eng">Dialogues of the Dead</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg067-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg067/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg067/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg067.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg067">
# <ti:label xml:lang="eng">Dialogues of the Sea-gods:</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg068-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg068/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg068/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg068.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg068">
# <ti:label xml:lang="eng">Dialogues of the Gods</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 1. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg069-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg069/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg069/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg069.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg069">
# <ti:label xml:lang="eng">Dialogues of the Hetaerae</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>
#
# created ctsfiles/tlg0062.tlg070-cts.xml
# outfname /Users/gcrane/github/first1kwork/data/tlg0062/tlg070/__cts__.xml
# writing /Users/gcrane/github/first1kwork/data/tlg0062/tlg070/__cts__.xml <ti:translation urn="urn:cts:greekLit:tlg0062.tlg070.perseus-eng4" xml:lang="eng" workUrn="urn:cts:greekLit:tlg0062.tlg070">
# <ti:label xml:lang="eng">The Purist Purized</ti:label>
# <ti:description xml:lang="eng">The Works of Lucian of Samosata, complete, with exceptions specified in the preface, Vol. 4. Fowler, H. W. and Fowler, F.G., translators. Oxford at the Clarendon Press, 1905.</ti:description>
#
# </ti:translation>
#
# </ti:work>

# %%
for foo in refsbook:
    print(foo)
# Out:
# <refsDecl n="CTS">
# <cRefPattern matchPattern="(\w+).(\w+)"
# replacementPattern="#xpath(/tei:TEI/tei:text/tei:body/tei:div/tei:div[@n='$1']/tei:div[@n='$2'])">
# <p>This pointer pattern extracts book and section</p>
# </cRefPattern>
# <cRefPattern matchPattern="(\w+)"
# replacementPattern="#xpath(/tei:TEI/tei:text/tei:body/tei:div/tei:div[@n='$1'])">
# <p>This pointer pattern extracts book</p>
# </cRefPattern>
# </refsDecl>

# %%
teiheader
# Out:
# ['<?xml version="1.0" encoding="UTF-8"?>',
#  '<?xml-model href="https://epidoc.stoa.org/schema/latest/tei-epidoc.rng" schematypens="http://relaxng.org/ns/structure/1.0"?>',
#  '<TEI xmlns="http://www.tei-c.org/ns/1.0">',
#  '<teiHeader xml:lang="eng">',
#  '<fileDesc>',
#  '<titleStmt>',
#  '<title xml:lang="eng">WORKTITLE</title>',
#  '<sponsor>Tufts University</sponsor>',
#  '<funder>National Endowment for the Humanities</funder>',
#  '<principal xml:id="GRC">Gregory Crane</principal>',
#  '<respStmt>',
#  '<persName>Gregory Crane</persName>',
#  '<resp>Digital conversion and editing</resp>',
#  '</respStmt>',
#  '',
#  '</titleStmt>',
#  '<publicationStmt>',
#  '<authority>Tufts University</authority>',
#  '<idno type="filename">IDNO</idno>',
#  '<authority>Perseus Digital Library</authority>',
#  '<idno type="filename">IDNO</idno>',
#  '<availability>',
#  '<licence target="https://creativecommons.org/licenses/by-sa/4.0/">Available under a Creative Commons Attribution-ShareAlike 4.0 International License</licence>',
#  '</availability>',
#  '<date>2023</date>',
#  '<publisher>Tufts University</publisher>',
#  '<pubPlace>Medford, MA, USA</pubPlace>',
#  '</publicationStmt>',
#  '<sourceDesc>',
#  '<listBibl xml:lang="eng">',
#  '<biblStruct>',
#  '<monogr>',
#  '<editor role="translator>"',
#  '<persName>',
#  '<name>Henry Watson Fowler</name>',
#  '</persName>',
#  '<persName>',
#  '<name>Francis George Fowler</name>',
#  '</persName>',
#  '</editor>',
#  '<author>Lucian</author>',
#  '<title xml:lang="eng">The works of Lucian of Samosata</title>',
#  '<imprint>',
#  '<publisher>Clarendon Press</publisher>',
#  '<pubPlace>Oxford</pubPlace>',
#  '<date>1905</date>',
#  '</imprint>',
#  '<biblScope unit="volume">4</biblScope>',
#  '</monogr>',
#  '<ref',
#  'target="https://archive.org/details/worksoflucianofs04luciuoft/page/PNUM/mode/1up" >Internet Archive</ref>',
#  '</biblStruct>',
#  '</listBibl>',
#  '</sourceDesc>',
#  '</fileDesc>',
#  '<encodingDesc>',
#  '<p>The following text is encoded in accordance with EpiDoc standards and with the CTS/CITE Architecture.</p>',
#  '<refsDecl n="CTS">',
#  '<cRefPattern n="section" matchPattern="(.+)" replacementPattern="#xpath(/tei:TEI/tei:text/tei:body/tei:div/tei:div[@n=\'$1\'])"/>',
#  '</refsDecl>',
#  '</encodingDesc>',
#  '<profileDesc>',
#  '<langUsage>',
#  '<language ident="en">English</language>',
#  '</langUsage>',
#  '</profileDesc>',
#  '</teiHeader>']
